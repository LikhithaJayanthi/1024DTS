# %% [markdown]
# # Yelp Analytics
# We are looking for some analysis using some transformation inside the yelp_checkin and yelp_business dataset. We want to find which businesses are having more checkins and why. Is there any suggestions that we can provide to the businesses so that the businesses can increase their checkins.
#
# First, we will load all the data to the SQlite database.

# %%
# code for reading json data cosuming less memory
import json
import pandas as pd
def init_ds(json):
    ds= {}
    keys = json.keys()
    for k in keys:
        ds[k]= []
    return ds, keys

def read_json(file):
    dataset = {}
    keys = []
    with open(file) as file_lines:
        for count, line in enumerate(file_lines):
            data = json.loads(line.strip())
            if count ==0:
                dataset, keys = init_ds(data)
            for k in keys:
                dataset[k].append(data[k])
                
        return pd.DataFrame(dataset)

# %% [markdown]
# ## Executing each read one by one to avoid crash

# %%
yelp_review= read_json('/kaggle/input/yelp-dataset/yelp_academic_dataset_review.json')

# %%
yelp_review.shape[0]
# Out:
# 6990280

# %%
yelp_checkin = read_json('/kaggle/input/yelp-dataset/yelp_academic_dataset_checkin.json')

# %%
yelp_tip = read_json('/kaggle/input/yelp-dataset/yelp_academic_dataset_tip.json')

# %%
yelp_user = read_json('/kaggle/input/yelp-dataset/yelp_academic_dataset_user.json')

# %% [markdown]
# ## Creating a SQL database and query data

# %%
import sqlite3

# Create an in-memory SQLite database
conn = sqlite3.connect('yelp_db')
cursor = conn.cursor()

# %% [markdown]
# ## Loading each of the dataframes to the database one by one

# %%
# Write the DataFrame to a SQLite table
yelp_review.to_sql('reviews', conn, index=False, if_exists='replace')
# Out:
# 6990280

# %%
yelp_checkin.to_sql('checking', conn, index=False, if_exists='replace')
# Out:
# 131930

# %%
yelp_tip.to_sql('tip', conn, index=False, if_exists='replace')
# Out:
# 908915

# %%
yelp_user.to_sql('user', conn, index=False, if_exists='replace')
# Out:
# 1987897

# %% [markdown]
# ### Yelp business file was a tricky one to load. Three columns needed to be converted into json and then was created as a seperate table

# %%
yelp_business = read_json('/kaggle/input/yelp-dataset/yelp_academic_dataset_business.json')

# %% [markdown]
# Seperating the json cols

# %%
yelp_business_json_cols = yelp_business[['business_id','attributes','hours']].copy()
yelp_business.drop(['attributes','hours'], axis=1, inplace=True)

# %% [markdown]
# ### Pushing the non json columns for now. Lets deal with the json columns later

# %%
yelp_business.to_sql('business', conn, index=False, if_exists='replace')
# Out:
# 150346

# %%
# handling the json columns 
yelp_business_json_cols.head()
# Out:
#               business_id                                         attributes  \
# 0  Pns2l4eNsfO8kk83dixA6A                      {'ByAppointmentOnly': 'True'}
# 1  mpf3x-BjTdTEA3yCZrAYPw             {'BusinessAcceptsCreditCards': 'True'}
# 2  tUFrWirKiKi_TAnsVWINQQ  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  MTSW4McQd7CbVtyjqoe9mw  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  mWMc6_wTdE0EUBKIGXDVfA  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %% [markdown]
# ## Creating a temp table for storing the json columns

# %%
cursor.execute('CREATE TABLE business_attributes (business_id TEXT, attributes TEXT, hours TEXT)')

# %%
# Convert dictionaries to JSON strings
yelp_business_json_cols['hours'] = yelp_business_json_cols['hours'].apply(json.dumps)

# %%
yelp_business_json_cols['attributes'] = yelp_business_json_cols['attributes'].apply(json.dumps)

# %% [markdown]
# ## Inserting all the columns of the json dataframe into the temptable

# %%
for row in yelp_business_json_cols.itertuples(index=False):
    cursor.execute('INSERT INTO business_attributes VALUES (?, ?, ?)', row)

# %%
query = '''
    SELECT * FROM business_attributes LIMIT 3

;'''

result = pd.read_sql_query(query, conn)
result
# Out:
#               business_id                                         attributes  \
# 0  Pns2l4eNsfO8kk83dixA6A                      {"ByAppointmentOnly": "True"}
# 1  mpf3x-BjTdTEA3yCZrAYPw             {"BusinessAcceptsCreditCards": "True"}
# 2  tUFrWirKiKi_TAnsVWINQQ  {"BikeParking": "True", "BusinessAcceptsCredit...
#
#                                                hours
# 0                                               null
# 1  {"Monday": "0:0-0:0", "Tuesday": "8:0-18:30", ...
# 2  {"Monday": "8:0-22:0", "Tuesday": "8:0-22:0", ...

# %%
query = '''
SELECT SUBSTR(
         hours,
         INSTR(hours, 'Monday')
       ) AS day
FROM business_attributes
WHERE business_id = 'tUFrWirKiKi_TAnsVWINQQ'


;'''

result = pd.read_sql_query(query, conn)
result
# Out:
#                                                  day
# 0  Monday": "8:0-22:0", "Tuesday": "8:0-22:0", "W...

# %%
query = '''
    SELECT * FROM business_attributes


;'''

result = pd.read_sql_query(query, conn)
result
# Out:
#                    business_id  \
# 0       Pns2l4eNsfO8kk83dixA6A
# 1       mpf3x-BjTdTEA3yCZrAYPw
# 2       tUFrWirKiKi_TAnsVWINQQ
# 3       MTSW4McQd7CbVtyjqoe9mw
# 4       mWMc6_wTdE0EUBKIGXDVfA
# ...                        ...
# 150341  IUQopTMmYQG-qRtBk-8QnA
# 150342  c8GjPIOTGVmIemT7j5_SyQ
# 150343  _QAMST-NrQobXduilWEqSw
# 150344  mtGm22y5c2UHNXDFAjaPNw
# 150345  jV_XOycEzSlTx-65W906pg
#
#                                                attributes  \
# 0                           {"ByAppointmentOnly": "True"}
# 1                  {"BusinessAcceptsCreditCards": "True"}
# 2       {"BikeParking": "True", "BusinessAcceptsCredit...
# 3       {"RestaurantsDelivery": "False", "OutdoorSeati...
# 4       {"BusinessAcceptsCreditCards": "True", "Wheelc...
# ...                                                   ...
# 150341  {"ByAppointmentOnly": "False", "RestaurantsPri...
# 150342  {"BusinessAcceptsCreditCards": "True", "Restau...
# 150343  {"RestaurantsPriceRange2": "1", "BusinessAccep...
# 150344  {"BusinessParking": "{'garage': False, 'street...
# 150345  {"WheelchairAccessible": "True", "BusinessAcce...
#
#                                                     hours
# 0                                                    null
# 1       {"Monday": "0:0-0:0", "Tuesday": "8:0-18:30", ...
# 2       {"Monday": "8:0-22:0", "Tuesday": "8:0-22:0", ...
# 3       {"Monday": "7:0-20:0", "Tuesday": "7:0-20:0", ...
# 4       {"Wednesday": "14:0-22:0", "Thursday": "16:0-2...
# ...                                                   ...
# 150341  {"Monday": "10:0-19:30", "Tuesday": "10:0-19:3...
# 150342  {"Monday": "9:30-17:30", "Tuesday": "9:30-17:3...
# 150343                                               null
# 150344  {"Monday": "9:0-20:0", "Tuesday": "9:0-20:0", ...
# 150345  {"Tuesday": "12:0-19:0", "Wednesday": "12:0-19...
#
# [150346 rows x 3 columns]

# %% [markdown]
# ## We have them sorted.

# %%
query = '''
    SELECT name,city,attributes,hours FROM business_attributes JOIN business
    WHERE business_attributes.business_id = business.business_id
    LIMIT 3

;'''

result = pd.read_sql_query(query, conn)
result
# Out:
#                        name           city  \
# 0  Abby Rappoport, LAC, CMQ  Santa Barbara
# 1             The UPS Store         Affton
# 2                    Target         Tucson
#
#                                           attributes  \
# 0                      {"ByAppointmentOnly": "True"}
# 1             {"BusinessAcceptsCreditCards": "True"}
# 2  {"BikeParking": "True", "BusinessAcceptsCredit...
#
#                                                hours
# 0                                               null
# 1  {"Monday": "0:0-0:0", "Tuesday": "8:0-18:30", ...
# 2  {"Monday": "8:0-22:0", "Tuesday": "8:0-22:0", ...

# %% [markdown]
# ### File Downloader Scripts

# %%
# %cd /kaggle/working
# Out:
# /kaggle/working

# %%
from IPython.display import FileLink 
FileLink(r'yelp_user.csv')
# Out:
# /kaggle/working/yelp_user.csv

# %% [markdown]
# # Final Project
#
#
# # Dataframes
# ## yelp_review
# ## yelp_checkin
# ## yelp_tip
# ## yelp_user
# ## yelp_business
#
# We will start the transformation process now

# %%
yelp_review.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0    3.0       0      0     0
# 1    5.0       1      0     1
# 2    3.0       0      0     0
# 3    5.0       1      0     1
# 4    4.0       1      0     1
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15

# %% [markdown]
# # make more columns for yelp_checkin

# %%
import matplotlib.pyplot as plt 
yelp_checkin.head()
# Out:
#               business_id                                               date
# 0  ---kPU91CF4Lq2-WlRu9Lw  2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# 1  --0iUa4sNDFiZFrAdIWhZQ  2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
# 2  --30_8IhuyMHbSOcNWd6DQ           2013-06-14 23:29:17, 2014-08-13 23:20:22
# 3  --7PUidqRWpRSpXebiyxTg  2011-02-15 17:12:00, 2011-07-28 02:46:10, 2012...
# 4  --7jw19RH9JKXgFohspgQw  2014-04-21 20:42:11, 2014-04-28 21:04:46, 2014...

# %% [markdown]
# Want to calculate how many checkins are there

# %%
# getting an extra column for filling up with the count of checkins
yelp_checkin['checkin_count'] = yelp_checkin['date'].apply(lambda x: len(x.split(',')))

# %%
yelp_checkin.head()
# Out:
#               business_id                                               date  \
# 0  ---kPU91CF4Lq2-WlRu9Lw  2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# 1  --0iUa4sNDFiZFrAdIWhZQ  2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
# 2  --30_8IhuyMHbSOcNWd6DQ           2013-06-14 23:29:17, 2014-08-13 23:20:22
# 3  --7PUidqRWpRSpXebiyxTg  2011-02-15 17:12:00, 2011-07-28 02:46:10, 2012...
# 4  --7jw19RH9JKXgFohspgQw  2014-04-21 20:42:11, 2014-04-28 21:04:46, 2014...
#
#    checkin_count
# 0             11
# 1             10
# 2              2
# 3             10
# 4             26

# %% [markdown]
# Creating a transformed checkin dataset for further analysis using Spark

# %%
# Split the comma-separated timestamps and convert them to datetime
yelp_checkin['date'] = yelp_checkin['date'].apply(lambda x: x.split(', '))
yelp_checkin['date'] = yelp_checkin['date'].apply(lambda x: [pd.to_datetime(ts, format='%Y-%m-%d %H:%M:%S') for ts in x])

# Define time ranges
morning_range = (6, 12)
afternoon_range = (12, 16)
evening_range = (16, 20)
night_range = (20, 24)  # Assuming 24-hour format, adjust if using AM/PM

# Function to categorize timestamps
def categorize_time(timestamps):
    categories = {
        'morning checking': 0,
        'afternoon checkin': 0,
        'evening checkin': 0,
        'night checkin': 0
    }
    for ts in timestamps:
        hour = ts.hour
        if morning_range[0] <= hour < morning_range[1]:
            categories['morning checking'] += 1
        elif afternoon_range[0] <= hour < afternoon_range[1]:
            categories['afternoon checkin'] += 1
        elif evening_range[0] <= hour < evening_range[1]:
            categories['evening checkin'] += 1
        else:
            categories['night checkin'] += 1
    return categories

# Apply categorization and count
yelp_checkin['Time_Categories'] = yelp_checkin['date'].apply(categorize_time)
yelp_checkin = pd.concat([yelp_checkin, yelp_checkin['Time_Categories'].apply(pd.Series)], axis=1)

# Rename columns for clarity
yelp_checkin.rename(columns={
    'morning checking': 'Morning Checkin',
    'afternoon checkin': 'Afternoon Checkin',
    'evening checkin': 'Evening Checkin',
    'night checkin': 'Night Checkin'
}, inplace=True)

# %%
yelp_checkin.head()
# Out:
#               business_id                                               date  \
# 0  ---kPU91CF4Lq2-WlRu9Lw  [2020-03-13 21:10:56, 2020-06-02 22:18:06, 202...
# 1  --0iUa4sNDFiZFrAdIWhZQ  [2010-09-13 21:43:09, 2011-05-04 23:08:15, 201...
# 2  --30_8IhuyMHbSOcNWd6DQ         [2013-06-14 23:29:17, 2014-08-13 23:20:22]
# 3  --7PUidqRWpRSpXebiyxTg  [2011-02-15 17:12:00, 2011-07-28 02:46:10, 201...
# 4  --7jw19RH9JKXgFohspgQw  [2014-04-21 20:42:11, 2014-04-28 21:04:46, 201...
#
#    checkin_count                                    Time_Categories  \
# 0             11  {'morning checking': 0, 'afternoon checkin': 1...
# 1             10  {'morning checking': 1, 'afternoon checkin': 1...
# 2              2  {'morning checking': 0, 'afternoon checkin': 0...
# 3             10  {'morning checking': 3, 'afternoon checkin': 3...
# 4             26  {'morning checking': 0, 'afternoon checkin': 1...
#
#    Morning Checkin  Afternoon Checkin  Evening Checkin  Night Checkin
# 0                0                  1                2              8
# 1                1                  1                1              7
# 2                0                  0                0              2
# 3                3                  3                2              2
# 4                0                 15                6              5

# %% [markdown]
# Saving the dataset so that we can load it easily

# %%
yelp_checkin.to_csv('yelp_checkin.csv')

# %% [markdown]
# ## yelp_tip

# %%
yelp_tip.sort_values(by='compliment_count', ascending=False)
# Out:
#                        user_id             business_id  \
# 543367  tsMF0FcFcHZ8i28WzWtQXw  dsfRniRgfbDjC8os848B6A
# 711663  661RwsBrt5ZbNhuipyhJcQ  x8-sTKZG59RUhgGj_kcyVg
# 244605  A4bsa7ykYRVCnb4h2vZALw  3Wy21heeDm8h2tSZfcj6OA
# 85848   G-l9ihg3sRAiGTuZLDmJTQ  5AOSTPOiZb7pnHJ6ICqqbA
# 545163  tsMF0FcFcHZ8i28WzWtQXw  pPpaOXOwcuO7z0sDghmOgw
# ...                        ...                     ...
# 305079  08mOpJRCpZe3D8UHszP4FA  AKrFJ7vuBbLPfE9u2HVEkQ
# 305080  tNx5cK6Ch83GyVwXItzEUA  Z0jh1QIoAdEdT19VARPu1Q
# 305081  05kMHFapG_z7YPZYhtIEEA  r4OWweOI9CAKk38pw_lSJA
# 305082  vBJ6YRLkZKzd1G9WQ56csg  OjHQumZ6nCh5vqzUbmkaNg
# 908914  4tF1CWdMxvvwpUIgGsDygA  _cb1Vg1NIWry8UA0jyuXnQ
#
#                                                      text  \
# 543367  Experience Bern's by sitting at the bar too . ...
# 711663            Brandon. Come here for your bbq.  Gush.
# 244605  30 minute wait for our drink order is unaccept...
# 85848      $8 drink menu, Velvet seats, and Dog friendly.
# 545163  Sumo oranges are in season. (Jan.- Mar.) They ...
# ...                                                   ...
# 305079                                            Outside
# 305080                                          Breffast.
# 305081                        Best place for local pizza!
# 305082  There are only two very large tables inside. ....
# 908914                  Food is good value but a bit hot!
#
#                        date  compliment_count
# 543367  2020-03-05 01:28:45                 6
# 711663  2016-06-11 15:37:07                 6
# 244605  2017-01-15 22:16:30                 5
# 85848   2014-11-06 01:01:18                 5
# 545163  2020-01-17 14:15:20                 5
# ...                     ...               ...
# 305079  2014-03-06 00:59:13                 0
# 305080  2011-04-02 14:03:50                 0
# 305081  2016-07-27 22:53:41                 0
# 305082  2016-11-09 20:10:57                 0
# 908914  2021-12-07 22:30:00                 0
#
# [908915 rows x 5 columns]

# %% [markdown]
# ## Most number of compliments are coming from...

# %%
query = '''
    SELECT COUNT(user_id) FROM tip 
    WHERE compliment_count in (6,5,4)


;'''

result = pd.read_sql_query(query, conn)
result
# Out:
#    COUNT(user_id)
# 0              19

# %% [markdown]
# 19 users only !

# %% [markdown]
# ## Most of the users dont give compliments

# %%
query = '''
    SELECT COUNT(user_id) FROM tip 
    WHERE compliment_count in (1,2,3)


;'''

result = pd.read_sql_query(query, conn)
result
# Out:
#    COUNT(user_id)
# 0           10520

# %%
query = '''
    SELECT COUNT(user_id) FROM tip 
    WHERE compliment_count = 0


;'''

result = pd.read_sql_query(query, conn)
result
# Out:
#    COUNT(user_id)
# 0          898376

# %% [markdown]
# ## Lets find number of distinct users who actually gave tips

# %%
query = '''
    SELECT COUNT(DISTINCT user_id) FROM tip 



;'''

result = pd.read_sql_query(query, conn)
result
# Out:
#    COUNT(DISTINCT user_id)
# 0                   301758

# %% [markdown]
# ## yelp_user

# %% [markdown]
# ##

# %%
pd.set_option('display.max_columns', None)
yelp_user.head()
# Out:
#                   user_id    name  review_count       yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585 2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333 2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665 2008-07-25 10:41:00    2086
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224 2005-11-29 04:38:33     512
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79 2007-01-05 19:40:59      29
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
# 3    330    299                                     2009,2010,2011
# 4     15      7
#
#                                              friends  fans  average_stars  \
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267           3.91
# 1  ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138           3.74
# 2  LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...    52           3.32
# 3  enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...    28           4.27
# 4  PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...     1           3.54
#
#    compliment_hot  compliment_more  compliment_profile  compliment_cute  \
# 0             250               65                  55               56
# 1            1145              264                 184              157
# 2              89               13                  10               17
# 3              24                4                   1                6
# 4               1                1                   0                0
#
#    compliment_list  compliment_note  compliment_plain  compliment_cool  \
# 0               18              232               844              467
# 1              251             1847              7054             3131
# 2                3               66                96              119
# 3                2               12                16               26
# 4                0                1                 1                0
#
#    compliment_funny  compliment_writer  compliment_photos  total_yelp_years  \
# 0               467                239                180                16
# 1              3131               1521               1946                14
# 2               119                 35                 18                15
# 3                26                 10                  9                17
# 4                 0                  0                  0                16
#
#    elite_count  friends_count
# 0            1          14995
# 1           14           4646
# 2            5            381
# 3            3            131
# 4            1             27

# %% [markdown]
# ## Make some calculated columns from the timestamp, elite count and friends count

# %%
from datetime import datetime
yelp_user['yelping_since'] = pd.to_datetime(yelp_user['yelping_since'])
target_date = datetime(2023, 8, 11)
yelp_user['total_yelp_years'] = yelp_user['yelping_since'].apply(lambda x: (target_date - x).days / 365.25)

# %%
yelp_user['total_yelp_years'] = yelp_user['total_yelp_years'].apply(int)

yelp_user.head()
# Out:
#                   user_id    name  review_count       yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585 2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333 2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665 2008-07-25 10:41:00    2086
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224 2005-11-29 04:38:33     512
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79 2007-01-05 19:40:59      29
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
# 3    330    299                                     2009,2010,2011
# 4     15      7
#
#                                              friends  fans  average_stars  \
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267           3.91
# 1  ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138           3.74
# 2  LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...    52           3.32
# 3  enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...    28           4.27
# 4  PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...     1           3.54
#
#    compliment_hot  compliment_more  compliment_profile  compliment_cute  \
# 0             250               65                  55               56
# 1            1145              264                 184              157
# 2              89               13                  10               17
# 3              24                4                   1                6
# 4               1                1                   0                0
#
#    compliment_list  compliment_note  compliment_plain  compliment_cool  \
# 0               18              232               844              467
# 1              251             1847              7054             3131
# 2                3               66                96              119
# 3                2               12                16               26
# 4                0                1                 1                0
#
#    compliment_funny  compliment_writer  compliment_photos  total_yelp_years  \
# 0               467                239                180                16
# 1              3131               1521               1946                14
# 2               119                 35                 18                15
# 3                26                 10                  9                17
# 4                 0                  0                  0                16
#
#    elite_count  friends_count
# 0            1          14995
# 1           14           4646
# 2            5            381
# 3            3            131
# 4            1             27

# %%
# make column for elite count and friends count 
yelp_user['elite_count'] = yelp_user['elite'].str.count(',') + 1
yelp_user['friends_count'] = yelp_user['friends'].str.count(',') + 1

# %%
yelp_user.head()
# Out:
#                   user_id    name  review_count       yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585 2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333 2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665 2008-07-25 10:41:00    2086
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224 2005-11-29 04:38:33     512
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79 2007-01-05 19:40:59      29
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
# 3    330    299                                     2009,2010,2011
# 4     15      7
#
#                                              friends  fans  average_stars  \
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267           3.91
# 1  ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138           3.74
# 2  LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...    52           3.32
# 3  enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...    28           4.27
# 4  PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...     1           3.54
#
#    compliment_hot  compliment_more  compliment_profile  compliment_cute  \
# 0             250               65                  55               56
# 1            1145              264                 184              157
# 2              89               13                  10               17
# 3              24                4                   1                6
# 4               1                1                   0                0
#
#    compliment_list  compliment_note  compliment_plain  compliment_cool  \
# 0               18              232               844              467
# 1              251             1847              7054             3131
# 2                3               66                96              119
# 3                2               12                16               26
# 4                0                1                 1                0
#
#    compliment_funny  compliment_writer  compliment_photos  total_yelp_years  \
# 0               467                239                180                16
# 1              3131               1521               1946                14
# 2               119                 35                 18                15
# 3                26                 10                  9                17
# 4                 0                  0                  0                16
#
#    elite_count  friends_count
# 0            1          14995
# 1           14           4646
# 2            5            381
# 3            3            131
# 4            1             27

# %% [markdown]
# Lets get this dataset saved as well

# %%
yelp_user.to_csv('yelp_user.csv')

# %%
# check if there is any duplicate entries
duplicate_user_ids = yelp_user[yelp_user.duplicated(subset='user_id', keep=False)]
duplicate_user_ids
# Out:
# Empty DataFrame
# Columns: [user_id, name, review_count, yelping_since, useful, funny, cool, elite, friends, fans, average_stars, compliment_hot, compliment_more, compliment_profile, compliment_cute, compliment_list, compliment_note, compliment_plain, compliment_cool, compliment_funny, compliment_writer, compliment_photos, total_yelp_years, elite_count, friends_count]
# Index: []

# %% [markdown]
# ## Check yelp_business

# %%
yelp_business.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           categories  categories_count
# 0  Doctors, Traditional Chinese Medicine, Naturop...               6.0
# 1  Shipping Centers, Local Services, Notaries, Ma...               5.0
# 2  Department Stores, Shopping, Fashion, Home & G...               6.0
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...               5.0
# 4                          Brewpubs, Breweries, Food               3.0

# %%
yelp_business_json_cols.head()
# Out:
#               business_id                                         attributes  \
# 0  Pns2l4eNsfO8kk83dixA6A                      {"ByAppointmentOnly": "True"}
# 1  mpf3x-BjTdTEA3yCZrAYPw             {"BusinessAcceptsCreditCards": "True"}
# 2  tUFrWirKiKi_TAnsVWINQQ  {"BikeParking": "True", "BusinessAcceptsCredit...
# 3  MTSW4McQd7CbVtyjqoe9mw  {"RestaurantsDelivery": "False", "OutdoorSeati...
# 4  mWMc6_wTdE0EUBKIGXDVfA  {"BusinessAcceptsCreditCards": "True", "Wheelc...
#
#                                                hours
# 0                                               null
# 1  {"Monday": "0:0-0:0", "Tuesday": "8:0-18:30", ...
# 2  {"Monday": "8:0-22:0", "Tuesday": "8:0-22:0", ...
# 3  {"Monday": "7:0-20:0", "Tuesday": "7:0-20:0", ...
# 4  {"Wednesday": "14:0-22:0", "Thursday": "16:0-2...

# %%
# making a column for number of categories. we also have yelp_business_json_cols dataframe and we will merge them here
yelp_business['categories_count'] = yelp_business['categories'].str.count(',') + 1
yelp_business_merged = pd.merge(yelp_business, yelp_business_json_cols, on='business_id')

yelp_business_merged.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           categories  categories_count  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...               6.0
# 1  Shipping Centers, Local Services, Notaries, Ma...               5.0
# 2  Department Stores, Shopping, Fashion, Home & G...               6.0
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...               5.0
# 4                          Brewpubs, Breweries, Food               3.0
#
#                                           attributes  \
# 0                      {"ByAppointmentOnly": "True"}
# 1             {"BusinessAcceptsCreditCards": "True"}
# 2  {"BikeParking": "True", "BusinessAcceptsCredit...
# 3  {"RestaurantsDelivery": "False", "OutdoorSeati...
# 4  {"BusinessAcceptsCreditCards": "True", "Wheelc...
#
#                                                hours
# 0                                               null
# 1  {"Monday": "0:0-0:0", "Tuesday": "8:0-18:30", ...
# 2  {"Monday": "8:0-22:0", "Tuesday": "8:0-22:0", ...
# 3  {"Monday": "7:0-20:0", "Tuesday": "7:0-20:0", ...
# 4  {"Wednesday": "14:0-22:0", "Thursday": "16:0-2...

# %%
yelp_business_merged['categories_count'] = pd.to_numeric(yelp_business_merged['categories_count'], errors='coerce').astype('Int64')

# %%
yelp_business_merged.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           categories  categories_count  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...                 6
# 1  Shipping Centers, Local Services, Notaries, Ma...                 5
# 2  Department Stores, Shopping, Fashion, Home & G...                 6
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...                 5
# 4                          Brewpubs, Breweries, Food                 3
#
#                                           attributes  \
# 0                      {"ByAppointmentOnly": "True"}
# 1             {"BusinessAcceptsCreditCards": "True"}
# 2  {"BikeParking": "True", "BusinessAcceptsCredit...
# 3  {"RestaurantsDelivery": "False", "OutdoorSeati...
# 4  {"BusinessAcceptsCreditCards": "True", "Wheelc...
#
#                                                hours
# 0                                               null
# 1  {"Monday": "0:0-0:0", "Tuesday": "8:0-18:30", ...
# 2  {"Monday": "8:0-22:0", "Tuesday": "8:0-22:0", ...
# 3  {"Monday": "7:0-20:0", "Tuesday": "7:0-20:0", ...
# 4  {"Wednesday": "14:0-22:0", "Thursday": "16:0-2...

# %%
yelp_business_merged.to_csv('yelp_business_merged.csv')

# %% [markdown]
# At this point, we will switch to another notebook where we will write analytical queries using Spark
